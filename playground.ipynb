# %%
from Bio import PDB

parser = PDB.PDBParser()
io = PDB.PDBIO()
struct = parser.get_structure('1a0q','/Users/jihyeonje/Downloads/PDBBind_processed/1a0q/1a0q_protein_processed.pdb')

for model in struct:
    for chain in model:
        for residue in chain:
            for atom in residue:
                x,y,z = atom.get_coord()

# %%
import torch
from Bio.PDB import *
import numpy as np

def load_coords_from_pdb(
    pdb,
    atoms,
    method="raw",
    also_bfactors=False,
    normalize_bfactors=True,
):
    """
    Returns array of shape (1, n_res, len(atoms), 3)
    """

    coords = []
    bfactors = []
    if method == "raw":  # Raw numpy implementation, faster than biopdb
        # Indexing into PDB format, allowing XXXX.XXX
        coords_in_pdb = [slice(30, 38), slice(38, 46), slice(46, 54)]
        # Indexing into PDB format, allowing XXX.XX
        bfactor_in_pdb = slice(60, 66)

        with open(pdb, "r") as f:
            resi_prev = 1
            counter = 0
            for l in f:
                l_split = l.rstrip("\n").split()
                if len(l_split) > 0 and l_split[0] == "ATOM" and l_split[2] in atoms:
                    resi = l_split[5]
                    if resi == resi_prev:
                        counter += 1
                    else:
                        counter = 0
                    if counter < len(atoms):
                        xyz = [
                            np.array(l[s].strip()).astype(float) for s in coords_in_pdb
                        ]
                        coords.append(xyz)
                        if also_bfactors:
                            bfactor = np.array(l[bfactor_in_pdb].strip()).astype(float)
                            bfactors.append(bfactor)
                    resi_prev = resi
            coords = torch.Tensor(np.array(coords)).view(1, -1, len(atoms), 3)

    return coords


def get_dmap(pdb, atoms, batched=True, out="torch", device=None):
    """
        Returns a n-dim array of shape (bs, 1, n, n)

    """
    coords = load_coords_from_pdb(pdb, atoms=atoms).view(1, -1, 3)
    coords = coords.contiguous()
    dmaps = torch.cdist(coords, coords).unsqueeze(1)
    return dmaps.detach().cpu().numpy()[0][0]

# %%
directory = '/Users/jihyeonje/Downloads/PDBBind_processed/'

ligpaths = []
protpaths = []

# iterate over files in
# that directory
for dir in os.listdir(directory):
    if dir !='.DS_Store':
        foldr = os.path.join(directory, dir)
    for i in os.listdir(foldr):
        if i.endswith('.sdf'):
            ligpaths.append(os.path.join(foldr, i))
        elif i.endswith('.pdb'):
            protpaths.append(os.path.join(foldr, i))

# %%
len(full_dist)
# Out:
# 1596

# %%
np.array(full_dist).shape
# Out:
# (1596, 1596)

# %%
pth = '/Users/jihyeonje/Downloads/PDBBind_processed/1mx1/1mx1_protein_processed.pdb'
bkbone_atms = ['CA', 'C', 'N']
full_dist = get_dmap(pth, bkbone_atms)
img2 = np.zeros((len(full_dist),len(full_dist),3))
img2[:,:,0] = full_dist
img2[:,:,1] = full_dist
img2[:,:,2] = full_dist

# %%
np.array(full_dist.append(get_dmap(pth, a))).shape
# Out:
# ()

# %%
for i in protpaths[:99]:
    full_dist = []
    bkbone_atms = [['CA'], ['C'], ['N']]
    for a in bkbone_atms:
        full_dist.append(get_dmap(i, a))
    print(i)
    print(np.asarray(full_dist).shape)
# Out:
# /Users/jihyeonje/Downloads/PDBBind_processed/6ugp/6ugp_protein_processed.pdb
# (3, 257, 257)
# /Users/jihyeonje/Downloads/PDBBind_processed/4hvb/4hvb_protein_processed.pdb
# (3, 830, 830)
# /Users/jihyeonje/Downloads/PDBBind_processed/2qki/2qki_protein_processed.pdb
# (3, 631, 631)
# /Users/jihyeonje/Downloads/PDBBind_processed/4rdn/4rdn_protein_processed.pdb
# (3, 149, 149)
# /Users/jihyeonje/Downloads/PDBBind_processed/3bwk/3bwk_protein_processed.pdb
# (3, 476, 476)
# /Users/jihyeonje/Downloads/PDBBind_processed/1bnm/1bnm_protein_processed.pdb
# (3, 257, 257)
# /Users/jihyeonje/Downloads/PDBBind_processed/4mo4/4mo4_protein_processed.pdb
# (3, 345, 345)
# /Users/jihyeonje/Downloads/PDBBind_processed/5yib/5yib_protein_processed.pdb
# (3, 328, 328)
# /Users/jihyeonje/Downloads/PDBBind_processed/3wzj/3wzj_protein_processed.pdb
# (3, 257, 257)
# /Users/jihyeonje/Downloads/PDBBind_processed/5o4s/5o4s_protein_processed.pdb
# (3, 112, 112)
# /Users/jihyeonje/Downloads/PDBBind_processed/4y7r/4y7r_protein_processed.pdb
# (3, 304, 304)
# /Users/jihyeonje/Downloads/PDBBind_processed/3s0b/3s0b_protein_processed.pdb
# (3, 119, 119)
# /Users/jihyeonje/Downloads/PDBBind_processed/1gww/1gww_protein_processed.pdb
# (3, 287, 287)
# /Users/jihyeonje/Downloads/PDBBind_processed/1xzx/1xzx_protein_processed.pdb
# (3, 249, 249)
# /Users/jihyeonje/Downloads/PDBBind_processed/2m0o/2m0o_protein_processed.pdb
# (3, 79, 79)
# /Users/jihyeonje/Downloads/PDBBind_processed/6a9c/6a9c_protein_processed.pdb
# (3, 66, 66)
# /Users/jihyeonje/Downloads/PDBBind_processed/5c7b/5c7b_protein_processed.pdb
# (3, 106, 106)
# /Users/jihyeonje/Downloads/PDBBind_processed/2gz8/2gz8_protein_processed.pdb
# (3, 612, 612)
# /Users/jihyeonje/Downloads/PDBBind_processed/4lv3/4lv3_protein_processed.pdb
# (3, 352, 352)
# /Users/jihyeonje/Downloads/PDBBind_processed/4qxr/4qxr_protein_processed.pdb
# (3, 364, 364)
# /Users/jihyeonje/Downloads/PDBBind_processed/3ch9/3ch9_protein_processed.pdb
# (3, 395, 395)
# /Users/jihyeonje/Downloads/PDBBind_processed/6r1d/6r1d_protein_processed.pdb
# (3, 106, 106)
# /Users/jihyeonje/Downloads/PDBBind_processed/4fvq/4fvq_protein_processed.pdb
# (3, 274, 274)
# /Users/jihyeonje/Downloads/PDBBind_processed/1iq1/1iq1_protein_processed.pdb
# (3, 426, 426)
# /Users/jihyeonje/Downloads/PDBBind_processed/6qat/6qat_protein_processed.pdb
# (3, 259, 259)
# /Users/jihyeonje/Downloads/PDBBind_processed/6dl9/6dl9_protein_processed.pdb
# (3, 716, 716)
# /Users/jihyeonje/Downloads/PDBBind_processed/2c6e/2c6e_protein_processed.pdb
# (3, 251, 251)
# /Users/jihyeonje/Downloads/PDBBind_processed/4lpf/4lpf_protein_processed.pdb
# (3, 190, 190)
# /Users/jihyeonje/Downloads/PDBBind_processed/3tfv/3tfv_protein_processed.pdb
# (3, 284, 284)
# /Users/jihyeonje/Downloads/PDBBind_processed/6e92/6e92_protein_processed.pdb
# (3, 257, 257)
# /Users/jihyeonje/Downloads/PDBBind_processed/4dus/4dus_protein_processed.pdb
# (3, 365, 365)
# /Users/jihyeonje/Downloads/PDBBind_processed/1kr3/1kr3_protein_processed.pdb
# (3, 227, 227)
# /Users/jihyeonje/Downloads/PDBBind_processed/3fwv/3fwv_protein_processed.pdb
# (3, 128, 128)
# /Users/jihyeonje/Downloads/PDBBind_processed/1r6z/1r6z_protein_processed.pdb
# (3, 499, 499)
# /Users/jihyeonje/Downloads/PDBBind_processed/1lhg/1lhg_protein_processed.pdb
# (3, 249, 249)
# /Users/jihyeonje/Downloads/PDBBind_processed/1qin/1qin_protein_processed.pdb
# (3, 352, 352)
# /Users/jihyeonje/Downloads/PDBBind_processed/5jna/5jna_protein_processed.pdb
# (3, 259, 259)
# /Users/jihyeonje/Downloads/PDBBind_processed/6azk/6azk_protein_processed.pdb
# (3, 431, 431)
# /Users/jihyeonje/Downloads/PDBBind_processed/4b5d/4b5d_protein_processed.pdb
# (3, 422, 422)
# /Users/jihyeonje/Downloads/PDBBind_processed/4cfv/4cfv_protein_processed.pdb
# (3, 264, 264)
# /Users/jihyeonje/Downloads/PDBBind_processed/5bmm/5bmm_protein_processed.pdb
# (3, 275, 275)
# /Users/jihyeonje/Downloads/PDBBind_processed/3sus/3sus_protein_processed.pdb
# (3, 504, 504)
# /Users/jihyeonje/Downloads/PDBBind_processed/4yrc/4yrc_protein_processed.pdb
# (3, 838, 838)
# /Users/jihyeonje/Downloads/PDBBind_processed/6o68/6o68_protein_processed.pdb
# (3, 261, 261)
# /Users/jihyeonje/Downloads/PDBBind_processed/3b26/3b26_protein_processed.pdb
# (3, 209, 209)
# /Users/jihyeonje/Downloads/PDBBind_processed/5xyx/5xyx_protein_processed.pdb
# (3, 337, 337)
# /Users/jihyeonje/Downloads/PDBBind_processed/3iaf/3iaf_protein_processed.pdb
# (3, 1106, 1106)
# /Users/jihyeonje/Downloads/PDBBind_processed/5ew9/5ew9_protein_processed.pdb
# (3, 257, 257)
# /Users/jihyeonje/Downloads/PDBBind_processed/3ads/3ads_protein_processed.pdb
# (3, 262, 262)
# /Users/jihyeonje/Downloads/PDBBind_processed/5mty/5mty_protein_processed.pdb
# (3, 328, 328)
# /Users/jihyeonje/Downloads/PDBBind_processed/6o0m/6o0m_protein_processed.pdb
# (3, 141, 141)
# /Users/jihyeonje/Downloads/PDBBind_processed/2v25/2v25_protein_processed.pdb
# (3, 231, 231)
# /Users/jihyeonje/Downloads/PDBBind_processed/4yt6/4yt6_protein_processed.pdb
# (3, 254, 254)
# /Users/jihyeonje/Downloads/PDBBind_processed/6g3a/6g3a_protein_processed.pdb
# (3, 328, 328)
# /Users/jihyeonje/Downloads/PDBBind_processed/4dzw/4dzw_protein_processed.pdb
# (3, 718, 718)
# /Users/jihyeonje/Downloads/PDBBind_processed/6cyi/6cyi_protein_processed.pdb
# (3, 229, 229)
# /Users/jihyeonje/Downloads/PDBBind_processed/4acm/4acm_protein_processed.pdb
# (3, 277, 277)
# /Users/jihyeonje/Downloads/PDBBind_processed/3zo4/3zo4_protein_processed.pdb
# (3, 355, 355)
# /Users/jihyeonje/Downloads/PDBBind_processed/2yga/2yga_protein_processed.pdb
# (3, 214, 214)
# /Users/jihyeonje/Downloads/PDBBind_processed/4hyf/4hyf_protein_processed.pdb
# (3, 227, 227)
# /Users/jihyeonje/Downloads/PDBBind_processed/5itd/5itd_protein_processed.pdb
# (3, 995, 995)
# /Users/jihyeonje/Downloads/PDBBind_processed/6bfw/6bfw_protein_processed.pdb
# (3, 393, 393)
# /Users/jihyeonje/Downloads/PDBBind_processed/6hf5/6hf5_protein_processed.pdb
# (3, 231, 231)
# /Users/jihyeonje/Downloads/PDBBind_processed/3rl8/3rl8_protein_processed.pdb
# (3, 90, 90)
# /Users/jihyeonje/Downloads/PDBBind_processed/5aqq/5aqq_protein_processed.pdb
# (3, 381, 381)
# /Users/jihyeonje/Downloads/PDBBind_processed/3n7r/3n7r_protein_processed.pdb
# (3, 174, 174)
# /Users/jihyeonje/Downloads/PDBBind_processed/2fjn/2fjn_protein_processed.pdb
# (3, 289, 289)
# /Users/jihyeonje/Downloads/PDBBind_processed/2x4s/2x4s_protein_processed.pdb
# (3, 373, 373)
# /Users/jihyeonje/Downloads/PDBBind_processed/4oc2/4oc2_protein_processed.pdb
# (3, 694, 694)
# /Users/jihyeonje/Downloads/PDBBind_processed/4mfe/4mfe_protein_processed.pdb
# (3, 596, 596)
# /Users/jihyeonje/Downloads/PDBBind_processed/5nn0/5nn0_protein_processed.pdb
# (3, 527, 527)
# /Users/jihyeonje/Downloads/PDBBind_processed/3uvl/3uvl_protein_processed.pdb
# (3, 303, 303)
# /Users/jihyeonje/Downloads/PDBBind_processed/1jd0/1jd0_protein_processed.pdb
# (3, 260, 260)
# /Users/jihyeonje/Downloads/PDBBind_processed/4f5y/4f5y_protein_processed.pdb
# (3, 386, 386)
# /Users/jihyeonje/Downloads/PDBBind_processed/1bai/1bai_protein_processed.pdb
# (3, 248, 248)
# /Users/jihyeonje/Downloads/PDBBind_processed/4oeg/4oeg_protein_processed.pdb
# (3, 124, 124)
# /Users/jihyeonje/Downloads/PDBBind_processed/4pnq/4pnq_protein_processed.pdb
# (3, 202, 202)
# /Users/jihyeonje/Downloads/PDBBind_processed/2avo/2avo_protein_processed.pdb
# (3, 198, 198)
# /Users/jihyeonje/Downloads/PDBBind_processed/4jzd/4jzd_protein_processed.pdb
# (3, 254, 254)
# /Users/jihyeonje/Downloads/PDBBind_processed/1ppi/1ppi_protein_processed.pdb
# (3, 496, 496)
# /Users/jihyeonje/Downloads/PDBBind_processed/5ir1/5ir1_protein_processed.pdb
# (3, 433, 433)
# /Users/jihyeonje/Downloads/PDBBind_processed/3d1e/3d1e_protein_processed.pdb
# (3, 366, 366)
# /Users/jihyeonje/Downloads/PDBBind_processed/1mx1/1mx1_protein_processed.pdb
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/jihyeonje/DALLE2-pytorch/dalle2_pytorch/playground.ipynb Cell 4 line 7
#       <a href='vscode-notebook-cell:/Users/jihyeonje/DALLE2-pytorch/dalle2_pytorch/playground.ipynb#X23sZmlsZQ%3D%3D?line=4'>5</a>     full_dist.append(get_dmap(i, a))
#       <a href='vscode-notebook-cell:/Users/jihyeonje/DALLE2-pytorch/dalle2_pytorch/playground.ipynb#X23sZmlsZQ%3D%3D?line=5'>6</a> print(i)
# ----> <a href='vscode-notebook-cell:/Users/jihyeonje/DALLE2-pytorch/dalle2_pytorch/playground.ipynb#X23sZmlsZQ%3D%3D?line=6'>7</a> print(np.asarray(full_dist).shape)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.

# %%
sdf_path = '/Users/jihyeonje/Downloads/PDBBind_processed/1a0q/1a0q_ligand.sdf'
suppl = Chem.SDMolSupplier(sdf_path)
smi = Chem.MolToSmiles(suppl[0])

# %%
ligtxts = []
for p in ligpaths:
    suppl = Chem.SDMolSupplier(p, sanitize=False)
    smi = Chem.MolToSmiles(suppl[0])

    ligtxts.append(smi)

# %%
import json
from PIL import Image

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from rdkit import Chem

import clip
from transformers import CLIPProcessor, CLIPModel

# %%
json_path = '/Users/jihyeonje/Downloads/archive/train_data.json'
image_path = '/Users/jihyeonje/Downloads/archive/images/train/'

with open(json_path, 'r') as f:
    input_data = []
    c = 0
    for line in f:
        obj = json.loads(line)
        input_data.append(obj)
        c+=1
        if c>49: break

# %%
# Load the CLIP model and processor
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")


# Choose computation device
device = "cuda:0" if torch.cuda.is_available() else "cpu"

# %%
# Load pre-trained CLIP model
model, preprocess = clip.load("ViT-B/32", device=device, jit=False)

# Define a custom dataset
class image_title_dataset():
    def __init__(self, list_image_path,list_txt):
        # Initialize image paths and corresponding texts
        self.image_path = list_image_path
        # Tokenize text using CLIP's tokenizer
        self.title  = clip.tokenize(list_txt, context_length=77, truncate=True)

    def __len__(self):
        return len(self.title)

    def __getitem__(self, idx):
        # Preprocess image using CLIP's preprocessing function
        full_dist = []
        bkbone_atms = [['CA'], ['C'], ['N']]
        for a in bkbone_atms:
            full_dist.append(get_dmap(self.image_path[idx], a))
        
        transform = T.ToPILImage()
        image = preprocess(transform(torch.tensor(full_dist)))
        title = self.title[idx]
        return image, title

# %%
full_dist = []
bkbone_atms = [['CA'], ['C'], ['N']]
for a in bkbone_atms:
    full_dist.append(get_dmap(pdb_path, a))
np.asarray(full_dist).shape

# %%
import torchvision
import torchvision.transforms as T

# %%
# import required module
import os
# assign directory
directory = '/Users/jihyeonje/Downloads/PDBBind_processed/'

ligpaths = []
protpaths = []

# iterate over files in
# that directory
for dir in os.listdir(directory):
    if dir !='.DS_Store':
        foldr = os.path.join(directory, dir)
    for i in os.listdir(foldr):
        if i.endswith('.sdf'):
            ligpaths.append(os.path.join(foldr, i))
        elif i.endswith('.pdb'):
            protpaths.append(os.path.join(foldr, i))

# %%
dataset = image_title_dataset(protpaths[:49], ligtxts[:49])
train_dataloader = DataLoader(dataset, batch_size=10, shuffle=True) #Define your own dataloader

# Function to convert model's parameters to FP32 format
def convert_models_to_fp32(model): 
    for p in model.parameters(): 
        p.data = p.data.float() 
        p.grad.data = p.grad.data.float()

# %%
if device == "cpu":
  model.float()

# Prepare the optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=5e-5,betas=(0.9,0.98),eps=1e-6,weight_decay=0.2) # the lr is smaller, more safe for fine tuning to new dataset


# Specify the loss function
loss_img = nn.CrossEntropyLoss()
loss_txt = nn.CrossEntropyLoss()

# %%
from tqdm import tqdm
# Train the model
num_epochs = 1
for epoch in range(num_epochs):
    pbar = tqdm(train_dataloader, total=len(train_dataloader))
    for batch in pbar:
        optimizer.zero_grad()

        images,texts = batch 
        
        images= images.to(device)
        texts = texts.to(device)

        # Forward pass
        logits_per_image, logits_per_text = model(images, texts)

        # Compute loss
        ground_truth = torch.arange(len(images),dtype=torch.long,device=device)
        total_loss = (loss_img(logits_per_image,ground_truth) + loss_txt(logits_per_text,ground_truth))/2

        # Backward pass
        total_loss.backward()
        if device == "cpu":
            optimizer.step()
        else : 
            convert_models_to_fp32(model)
            optimizer.step()
            clip.model.convert_weights(model)

        pbar.set_description(f"Epoch {epoch}/{num_epochs}, Loss: {total_loss.item():.4f}")
# Out:
# Epoch 0/1, Loss: 2.4980: 100%|██████████| 5/5 [00:18<00:00,  3.73s/it]

# %%
model
# Out:
# CLIP(
#   (visual): VisionTransformer(
#     (conv1): Conv2d(3, 768, kernel_size=(32, 32), stride=(32, 32), bias=False)
#     (ln_pre): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (transformer): Transformer(
#       (resblocks): Sequential(
#         (0): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (6): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (7): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (8): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (9): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (10): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (11): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (ln_post): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (transformer): Transformer(
#     (resblocks): Sequential(
#       (0): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (6): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (7): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (8): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (9): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (10): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (11): ResidualAttentionBlock(
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): QuickGELU()
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (token_embedding): Embedding(49408, 512)
#   (ln_final): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
# )
